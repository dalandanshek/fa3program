# %% [markdown]
# <a href="https://colab.research.google.com/github/dalandanshek/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter student's name:")
age = input("Enter student's age:")
course = input("Enter student's course:")

print("---STUDENT INFORMATION")
print(f"Name: {name}")
print(f"Age: {age}")
print(f"Course: {course}")
print("----------------------")

# %%
score = input("Enter student's score:")
if int(score) >= 75:
  print("Passed")
else:
  print("Failed")

# %%
name = input("Enter student's name:")
score = input("Please enter student's score:")
if int(score) >= 90:
  print("A")
elif int(score) >= 80 <= 89:
  print("B")
elif int(score) >= 70 <= 79:
  print("C")
else:
  print("F")
